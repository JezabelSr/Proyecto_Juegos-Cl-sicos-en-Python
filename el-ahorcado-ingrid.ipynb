# %% [markdown]
# # JUEGO: EL AHORCADO
#
# **FASE INICIAL**

# %% [markdown]
# OBJETIVO:
#
# -Elegir palabra secreta
#
# -crear tablero, mostrar la palabra oculta con guiones (_ _ _ _ _)
#
# Pedir letras al jugador (input)
#
# crear lista con letras usadas vacia[]
#
# El jugador intenta adivinarla letra por letra.
#
# Si acierta, se muestran esas letras correctas.
#
# numero de intentos
#
# Si falla, pierde un intento.
#
# restar intentos si falla
#
# El juego termina cuando:
#
# adivina toda la palabra, o se queda sin intentos.

# %%
# 1. Palabra secreta
palabra_secreta = "gato"

# 2. Crear el tablero
tablero = ["_"] * len(palabra_secreta)

# 3. almacenar las letras usadas por el jugador
letras_usadas = []

# 4. crear numero de intentos
intentos = 6

# %%
tablero
# Out:
# ['_', '_', '_', '_']

# %%
# Pedir una letra
letra = input("Introduce una letra: ").lower()

# Guardar la letra en letras usadas
letras_usadas.append(letra)

# Comprobar que la letra este en la palabra
if letra in palabra_secreta:
    print("¡Bien! La letra está en la palabra")

# %%
# Actualizar el tablero
    for l in range(len(palabra_secreta)):
        if palabra_secreta[l] == letra:
            tablero[l] = letra

else:
    print("Has fallado!! no te quedan mas intentos")
intentos = -1
